# %%
import rootpath
import sys
sys.path.append(rootpath.detect())

import numpy as np
import matplotlib.pyplot as plt
import wfg
from tqdm import tqdm
from testsuite.utilities import Pareto_split

# %%
## 2D
M = 2                                   # Number of objectives
kfactor = 1
lfactor = 1
k = kfactor*(M-1)   # position related params
l = lfactor*2           # distance related params

n_dim = k+l
n_obj = M
func = wfg.WFG3


M = n_obj
N = 5000
y = np.zeros((N, n_obj))
x = np.zeros((N, n_dim))
for n in tqdm(range(N)):
    z = wfg.random_soln(k, l, func.__name__)
    y[n,:] = func(z, k, M)
    x[n,:] = z
# Out:
# 100%|██████████| 5000/5000 [00:00<00:00, 160919.56it/s]

# %%
pi, di = Pareto_split(y, return_indices=True)

# %%
y2 = np.load("./wfg3_2d_refpoints")

# %%
y.shape
# Out:
# (5000, 2)

# %%
fig = plt.figure(figsize=[17, 8])
ax0 = fig.add_subplot(121)
ax1 = fig.add_subplot(122)

# ax0.scatter(*y.T, s=5, c="C0")
ax0.scatter(*y[pi].T, s=5, c="C0")
ax0.scatter(*y[di].T, s=5, c="C1")
ax1.scatter(*y2.T, s=5, c="C2")

# %%
fig = plt.figure(figsize=[17, 8])
ax0 = fig.gca()

ax0.scatter(*y[pi].T, s=5, c="C0")
# ax0.scatter(*y[di].T, s=5, c="C1")
ax0.scatter(*y2.T, s=5, c="C2")

# %%
## 3D
M = 3                                   # Number of objectives
kfactor = 1
lfactor = 1
k = kfactor*(M-1)   # position related params
l = lfactor*2           # distance related params

n_dim = k+l
n_obj = M
func = wfg.WFG3


M = n_obj
N = 5000
y = np.zeros((N, n_obj))
x = np.zeros((N, n_dim))
for n in tqdm(range(N)):
    z = wfg.random_soln(k, l, func.__name__)
    y[n,:] = func(z, k, M)
    x[n,:] = z
# Out:
# 100%|██████████| 5000/5000 [00:00<00:00, 88426.24it/s]

# %%
pi, di = Pareto_split(y, return_indices=True)

# %%
y3 = np.load("./wfg3_3d_refpoints")

# %%
fig = plt.figure(figsize=[17, 8])
ax0 = fig.add_subplot(121, projection="3d")
ax1 = fig.add_subplot(122, projection="3d")

# ax0.scatter(*y.T, s=5, c="C0")
ax0.scatter(*y[pi].T, s=5, c="C0")
ax0.scatter(*y[di].T, s=5, c="C1")
ax1.scatter(*y3.T, s=5, c="C2")

# %%
fig = plt.figure(figsize=[17, 8])
ax0 = fig.gca(projection="3d")

ax0.scatter(*y[pi].T, s=5, c="C0", alpha=0.1)
# ax0.scatter(*y[di].T, s=5, c="C1")
ax0.scatter(*y3.T, s=5, c="C1")

# %%
## 4D
M = 4                                   # Number of objectives
kfactor = 1
lfactor = 1
k = kfactor*(M-1)   # position related params
l = lfactor*2           # distance related params

n_dim = k+l
n_obj = M
func = wfg.WFG3


M = n_obj
N = 5000
y = np.zeros((N, n_obj))
x = np.zeros((N, n_dim))
for n in tqdm(range(N)):
    z = wfg.random_soln(k, l, func.__name__)
    y[n,:] = func(z, k, M)
    x[n,:] = z
# Out:
# 100%|██████████| 5000/5000 [00:00<00:00, 164563.82it/s]

# %%
pi, di = Pareto_split(y, return_indices=True)

# %%
y4 = np.load("./wfg3_4d_refpoints")

# %%
ypi, ydi = Pareto_split(y4, return_indices=True)

# %%
fig = plt.figure(figsize=[17, 8])
ax0 = fig.add_subplot(121, projection="3d")
ax1 = fig.add_subplot(122, projection="3d")

# ax0.scatter(*y.T, s=5, c="C0")
ax0.scatter(*y[di, :3].T, s=5, c="C0")
ax0.scatter(*y[pi, :3].T, s=5, c="C1")
ax1.scatter(*y4[ydi, :3].T, s=5, c="C0")
ax1.scatter(*y4[ypi, :3].T, s=5, c="C1")

# %%
fig = plt.figure(figsize=[17, 8])
ax0 = fig.add_subplot(121, projection="3d")
ax1 = fig.add_subplot(122, projection="3d")

# ax0.scatter(*y.T, s=5, c="C0")
ax0.scatter(*y[:, [0, 2, 3]].T, s=5, c="C1")
ax1.scatter(*y4[:, [0, 2, 3]].T, s=5, c="C1")

# %%
fig = plt.figure(figsize=[17, 8])
ax0 = fig.add_subplot(121, projection="3d")
ax1 = fig.add_subplot(122, projection="3d")

# ax0.scatter(*y.T, s=5, c="C0")
ax0.scatter(*y[:, [1, 2, 3]].T, s=5, c="C1")
ax1.scatter(*y4[:, [1, 2, 3]].T, s=5, c="C1")

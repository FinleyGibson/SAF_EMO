# %%
import sys
import rootpath
sys.path.append(rootpath.detect())

import wfg
import numpy as np
import matplotlib.pyplot as plt
from experiments.igd_refpoints.igd_utilities import *
from testsuite.utilities import Pareto_split 
import matplotlib.patches as patches
from scipy.spatial import KDTree

func = wfg.WFG3

# %% [markdown]
# ### wfg3_2obj_10dim

# %%
try:
    with open('data/wfg3_2d_refpoints', 'rb') as infile:
        yf_2 = np.load(infile)
    wfg3_2obj_10dim_loaded = True
    print("2D data: loaded")
except FileNotFoundError:
    wfg3_2obj_10dim_loaded = False
    print("2D data: not found")
# Out:
# 2D data: loaded

# %%
M = 2                                   # Number of objectives
kfactor = 1
lfactor = 1
k = kfactor*(M-1)   # position related params
l = lfactor*2           # distance related params


n_dim = k+l
n_obj = M

N = 5000
y0 = np.zeros((N, n_obj))
x0 = np.zeros((N, n_dim))
for n in range(N):
    z = wfg.random_soln(k, l, func.__name__)
    y0[n,:] = func(z, k, M)
    x0[n,:] = z


# sample with k and l factors
kfactor = 4
lfactor = 3
k = kfactor*(M-1)   # position related params
l = lfactor*2       # distance related params

n_dim = k+l
y = np.zeros((N, n_obj))
x = np.zeros((N, n_dim))
for n in range(N):
    z = wfg.random_soln(k, l, func.__name__)
    y[n,:] = func(z, k, M)
    x[n,:] = z

# %%
fig = plt.figure(figsize = [10, 10])
ax0 = fig.add_subplot(121)
ax1 = fig.add_subplot(122)
ax0.scatter(*yf_2.T, c="C3", s=55)
ax0.scatter(*y0.T, c="C0", marker=".", s=5)
ax0.scatter(*y.T, c="C1", marker=".", s=5)
ax0.set_aspect('equal')
rect = patches.Rectangle((1.7, 0.2),0.2,0.2,linewidth=1,edgecolor='r',facecolor='none')
ax0.add_patch(rect)

ax1.set_xlim([1.7, 1.9])
ax1.set_ylim([0.2, 0.4])
ax1.scatter(*yf_2.T, c="C3", s=55)
ax1.scatter(*y0.T, c="C0", marker=".", s=5)
ax1.scatter(*y.T, c="C1", s=55)
ax1.set_aspect('equal')

# %%
with open('data/wfg3_2obj_10dim_refpoints', 'wb') as outfile:
        np.save(outfile, yf_2)
with open('data/wfg3_2obj_6dim_refpoints', 'wb') as outfile:
        np.save(outfile, yf_2)

# %% [markdown]
# ### wfg3_3obj_10dim

# %%
try:
    with open('data/wfg3_3d_refpoints', 'rb') as infile:
        yf_3 = np.load(infile)
    wfg3_2obj_10dim_loaded = True
    print("2D data: loaded")
except FileNotFoundError:
    wfg3_2obj_10dim_loaded = False
    print("2D data: not found")

# %%
M = 3  # Number of objectives
kfactor = 1
lfactor = 1
k = kfactor*(M-1)   # position related params
l = lfactor*2   

n_dim = k+l
n_obj = M

N = 50000
y0 = np.zeros((N, n_obj))
x0 = np.zeros((N, n_dim))
for n in range(N):
    z = wfg.random_soln(k, l, func.__name__)
    y0[n,:] = func(z, k, M)
    x0[n,:] = z


# sample with k and l factors
kfactor = 3
lfactor = 2
k = kfactor*(M-1)   # position related params
l = lfactor*2       # distance related params

n_dim = k+l
y = np.zeros((N, n_obj))
x = np.zeros((N, n_dim))
for n in range(N):
    z = wfg.random_soln(k, l, func.__name__)
    y[n,:] = func(z, k, M)
    x[n,:] = z

# %%
fig = plt.figure(figsize = [10, 10])
ax0 = fig.add_subplot(121, projection="3d")
ax1 = fig.add_subplot(122, projection="3d")
ax0.scatter(*yf_3.T, c="C3", s=15 , alpha=0.01)
ax0.scatter(*y0.T, c="C0", marker=".", s=5)
ax0.scatter(*y.T, c="C1", marker=".", s=5)

ax1.set_xlim([0.9, 1.])
ax1.set_ylim([0.9, 2.1])
ax1.set_zlim([0., .9])
ax1.scatter(*yf_3.T, c="C3", s=25 , alpha=0.1)
ax1.scatter(*y0.T, c="C0", marker=".", s=5)
ax1.scatter(*y.T, c="C1", s=5)
    
ax0.set_xlabel("x")
ax0.set_ylabel("y")
ax0.set_zlabel("z")
# Out:
# Text(0.5, 0, 'z')

# %%
with open('data/wfg3_3obj_10dim_refpoints', 'wb') as outfile:
        np.save(outfile, yf_3)
with open('data/wfg3_3obj_6dim_refpoints', 'wb') as outfile:
        np.save(outfile, yf_3)

# %% [markdown]
# ### wfg3_4obj_10dim

# %%
try:
    with open('data/wfg3_4d_refpoints', 'rb') as infile:
        yf_4 = np.load(infile)
    wfg4_2obj_10dim_loaded = True
    print("2D data: loaded")
except FileNotFoundError:
    wfg4_2obj_10dim_loaded = False
    print("2D data: not found")
# Out:
# 2D data: loaded

# %%
M = 4  # Number of objectives
kfactor = 1
lfactor = 1
k = kfactor*(M-1)   # position related params
l = lfactor*2   

n_dim = k+l
n_obj = M

N = 50000
y0 = np.zeros((N, n_obj))
x0 = np.zeros((N, n_dim))
for n in range(N):
    z = wfg.random_soln(k, l, func.__name__)
    y0[n,:] = func(z, k, M)
    x0[n,:] = z


# sample with k and l factors
kfactor = 3
lfactor = 2
k = kfactor*(M-1)   # position related params
l = lfactor*2       # distance related params

n_dim = k+l
y = np.zeros((N, n_obj))
x = np.zeros((N, n_dim))
for n in range(N):
    z = wfg.random_soln(k, l, func.__name__)
    y[n,:] = func(z, k, M)
    x[n,:] = z

# %%
fig = plt.figure(figsize = [20, 10])
ax0 = fig.add_subplot(121)
ax1 = fig.add_subplot(122)

ax0.scatter(*yf_4[:, :2].T, c="C3", s=35 , alpha=0.1)
ax0.scatter(*y0[:, :2].T, c="C0", marker=".", s=5)
ax0.scatter(*y[:, :2].T, c="C1", s=5)

ax1.scatter(*yf_4[:, 2:].T, c="C3", s=35 , alpha=0.1)
ax1.scatter(*y0[:, 2:].T, c="C0", marker=".", s=5)
ax1.scatter(*y[:, 2:].T, c="C1", s=5)

ax1.scatter(*yf_4[:, 2:].T, c="C3", s=35 , alpha=0.1)
ax1.scatter(*y0[:, 2:].T, c="C0", marker=".", s=5)
ax1.scatter(*y[:, 2:].T, c="C1", s=5)

# %%
with open('data/wfg3_4obj_10dim_refpoints', 'wb') as outfile:
        np.save(outfile, yf_4)
